# %% [markdown]
# <a href="https://colab.research.google.com/github/cnoob068-ux/python-practice/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1=int(input("pick a number:"))
num2=int(input("pick second number"))
total=num1+num2
print(total)
# Out:
# pick a number:56
# pick second number67
# 123

# %%
a=float(input("sise of the square:"))
print("area of sqaure=",a*a)
# Out:
# sise of the square:1.56
# area of sqaure= 2.4336

# %%
a=float(input("pick a number:"))
b=float(input("pick second number"))
avg=(a+b)/2
print(avg)
# Out:
# pick a number:34
# pick second number2
# 18.0

# %%
a=float(input("pick a number:"))
b=float(input("pick second number:"))
print(a>=b)
# Out:
# pick a number:46
# pick second number:15
# True
