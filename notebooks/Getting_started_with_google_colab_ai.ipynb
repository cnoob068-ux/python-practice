# %%
print("i am aksh")
# Out:
# i am aksh

# %%
print("17")
# Out:
# 17

# %%
print("richard parker")
# Out:
# richard parker

# %%
name=input("enter name")
print(name)
# Out:
# enter nameakki
# akki

# %%
age=input("what your age")
print(age)
# Out:
# what your age17
# 17

# %%
colour=input("your favourite coloue")
print(colour)
# Out:
# your favourite colouegreen
# green
